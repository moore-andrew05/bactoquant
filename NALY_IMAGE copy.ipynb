# %%
import numpy as np
from skimage import io
import matplotlib.pyplot as plt
import os

# %%
path = "/Volumes/BIG_DATA/04_DATA/03_NALY_ERM1_LOC/RTR/control/"

image_names = os.listdir(path)
image_names = [name for name in image_names if not name.startswith("._")]

# %%
image_names
# Out:
# ['MAX_220914_permed_wNT002_0uM_Noco_09_R3D.tif',
#  'MAX_220914_permed_wNT002_0uM_Noco_11_R3D.tif',
#  'MAX_220914_permed_wNT002_0uM_Noco_10_R3D.tif',
#  'MAX_220914_permed_wNT002_0uM_Noco_12_R3D.tif',
#  'MAX_220914_permed_wNT002_0uM_Noco_13_R3D.tif',
#  'MAX_220927_permed_wNT002_0uM_Noco_21_R3D.tif',
#  'MAX_220927_permed_wNT002_0uM_Noco_22_R3D.tif']

# %%
imgs = [io.imread(path + imname)[:,:,1] for imname in image_names]

# %%
io.imshow(imgs[4])

# %%
np.quantile(img2)
# Out:
# 96.0

# %%
img[img< np.quantile(img, 0.95)] = 0

# %%
io.imshow(img)

# %%
img2[img2 < np.quantile(img2, 0.95)] = 0

# %%
# Out:
# 0

# %%
io.imshow(img2)

# %%
imgs = [img, img2]

# %%
imgs[0].shape
# Out:
# (388, 685)

# %%
flat = []
for img in imgs:
    flat.append(np.sum(img,axis=0))

# %%
flat[1].shape
# Out:
# (584,)

# %%
flat_ints = []
for f in flat:
    flat_ints.append(_interp1d(f, 1000))

# %%
flat_ints[0].shape
# Out:
# (1000,)

# %%
def _interp1d(array, new_len):
        la = len(array)
        return np.interp(np.linspace(0, la - 1, num=new_len), np.arange(la), array)

# %%
plt.plot(flat_ints[1])
plt.plot(flat_ints[0]);

# %%
plt.plot(flat_int)
